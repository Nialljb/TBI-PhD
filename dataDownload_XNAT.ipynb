# %% [markdown]
# # Full project downloading data from XNAT
#
# #### Maria Yanez Lopez 2018 (maria.yanez-lopez@imperial.ac.uk)
# #### ~ adapted for full project download Niall Bourke Feb 2019 (n.bourke@imperial.ac.uk)
# ### Documentation:
#
# https://github.com/pyxnat/pyxnat/blob/master/pyxnat/core/downloadutils.py
#
# https://groups.google.com/forum/#!topic/xnat_discussion/K8h4VP4CBMg
#
# https://gist.github.com/mattsouth/db8f2d09acf3c57ba605fa93c4e8d03e
#
# https://ubuntuforums.org/showthread.php?t=786879
#
# https://wiki.imperial.ac.uk/pages/viewpage.action?spaceKey=HPC&title=Jupyter
#
# Version 2.0 ~ Niall Bourke
# Updated 24/09/2019
# ~ Checks for data that is already pulled from xnat to allow rolling updating of data on the HPC
#
# This scripts downloads DICOM data from XNAT according to users specifications.
#
# Works with python version py2.7 (upadte envionment libraries for py3 for continued support)

# %% [markdown]
# ### Import python libraries

# %%
import sys, os, getpass                           
from pyxnat import Interface

# %% [markdown]
# ### Introduce your XNAT login details (same as college credentials) and project folder

# %%
userName = raw_input('Type XNAT User Name: ')
passWord = getpass.getpass('Type XNAT Password: ')
projectID = raw_input('Type XNAT Project ID: ')
server = 'http://cif-xnat.hh.med.ic.ac.uk'
# Out:
# Type XNAT User Name:  nbourke
# Type XNAT Password:  ·········
# Type XNAT Project ID:  BIO-AX-TBI

# %%
print 'INPUT'
print 'Server: ', server
print 'Username: ', userName
print 'Password: ', ''.join(['*']*len(passWord))
print 'ProjectID: ', projectID
# Out:
# INPUT
# Server:  http://cif-xnat.hh.med.ic.ac.uk
# Username:  nbourke
# Password:  *********
# ProjectID:  BIO-AX-TBI

# %% [markdown]
# ### Create PYXNAT interface

# %%
central = Interface(server=server, user=userName, password=passWord)

# Full project download:
subjects = central.select.project(projectID).subjects().get()

# individual subject:
#subID="CIF02_S00677"
#subjects = central.select.project(projectID).subjects(subID).get()

print(subjects)
allSessions = []
number_subjects = 0
# Out:
# ['CIF02_S00423', 'CIF02_S00424', 'CIF_S00714', 'CIF02_S00425', 'CIF02_S00426', 'CIF02_S00427', 'CIF_S01259', 'CIF02_S00728', 'CIF02_S00606', 'CIF02_S00738', 'CIF02_S00798', 'CIF02_S00823', 'CIF02_S00833', 'CIF02_S00869', 'CIF02_S00872', 'CIF02_S00874', 'CIF02_S00877', 'CIF02_S00922', 'CIF02_S00949', 'CIF02_S01022', 'CIF02_S01023', 'CIF02_S01069', 'CIF02_S01070', 'CIF02_S01073', 'CIF02_S01074', 'CIF02_S01075', 'CIF02_S01076', 'CIF02_S01077', 'CIF02_S01078', 'CIF02_S01079', 'CIF02_S00430', 'CIF02_S00432', 'CIF_S02259', 'CIF02_S00440', 'CIF02_S00472', 'CIF02_S00476', 'CIF02_S00477', 'CIF02_S00108', 'CIF02_S00746', 'CIF02_S00747', 'CIF02_S00761', 'CIF02_S00762', 'CIF02_S00777', 'CIF02_S00778', 'CIF02_S00793', 'CIF02_S00799', 'CIF02_S00816', 'CIF02_S00819', 'CIF02_S00820', 'CIF02_S00821', 'CIF02_S00471', 'CIF02_S00822', 'CIF02_S00899', 'CIF02
'CIF02_S01289', 'CIF02_S01291', 'CIF02_S01290', 'CIF02_S01293', 'CIF02_S01294', 'CIF02_S01295', 'CIF_S02123', 'CIF_S02183', 'CIF02_S00371', 'CIF02_S00375', 'CIF02_S00377', 'CIF02_S00381', 'CIF02_S00383', 'CIF02_S00384', 'CIF02_S00385', 'CIF02_S00386', 'CIF02_S00387', 'CIF02_S00388', 'CIF02_S00389', 'CIF02_S00390', 'CIF02_S00391', 'CIF02_S00473', 'CIF02_S00480', 'CIF02_S00368', 'CIF02_S00505', 'CIF02_S01019', 'CIF02_S01021', 'CIF02_S01030', 'CIF02_S01032', 'CIF02_S01055', 'CIF02_S00474', 'CIF02_S00392', 'CIF02_S00395', 'CIF02_S00397', 'CIF02_S00403', 'CIF02_S00405', 'CIF02_S00479', 'CIF02_S00592', 'CIF02_S00594', 'CIF02_S00599', 'CIF02_S00600', 'CIF02_S00601', 'CIF02_S00602', 'CIF02_S00603', 'CIF02_S00604', 'CIF02_S00605', 'CIF02_S00608', 'CIF02_S00609', 'CIF02_S01157', 'CIF02_S01158', 'CIF02_S01162', 'CIF02_S01185', 'CIF02_S01190', 'CIF02_S011 ...

# %% [markdown]
# ### Browse through project, collect subjects/sessions/scans and print subject labels

# %%
for i, subject in enumerate(subjects):
    label = central.select.project(projectID).subject(subject).label()
    print label, ('%i/%i' % (i+1, len(subjects)))
    sessions = central.select.project(projectID).subjects(subject).experiments().get()
    allSessions.append(sessions)
# Out:
# IT4381265 1/346
# SI0092660 2/346
# CIF0608 3/346
# IT4381266 4/346
# IT4381269 5/346
# IT4381272 6/346
# CIF1075 7/346
# IT079C001 8/346
# IT6516127 9/346
# SI0092827 10/346
# CIF2581 11/346
# IT079C006 12/346
# CH001C004 13/346
# CIF2646 14/346
# IT078C005 15/346
# IT4381513 16/346
# CIF2654 17/346
# CIF2691 18/346
# IT4381525 19/346
# CH001C010 20/346
# CH001C008 21/346
# SI009C006 22/346
# SI009C007 23/346
# IT078C007 24/346
# SI009C008 25/346
# SI009C009 26/346
# SI009C010 27/346
# SI009C011 28/346
# IT651C001 29/346
# IT651C002 30/346
# CH0010016 31/346
# CH0010014 32/346
# CIF1757 33/346
# CIF2277 34/346
# IT4381209 35/346
# IT4381273 36/346
# IT4381274 37/346
# CH0010001 38/346
# IT6516397 39/346
# CIF2550 40/346
# IT438C001 41/346
# CIF2551 42/346
# CIF2566 43/346
# IT6516386 44/346
# IT438C002 45/346
# CIF2582 46/346
# CIF2588 47/346
# IT438C003 48/346
# IT0781663 49/346
# SI0092710 50/346
# IT0794629 51/346
# IT079C005 52/346
# CIF2671 53/346
# CIF2675 54/346
# CH001C003 55/346
# CH001C007 56/346
# IT6516576 57/346
# CH001C014 58/346
# IT0791082 59/346
# CH0010034 60/346
# SI0092993 61/346
# SI0092997 62/346
# SI009C013 63/346
# CH0010038 64/346
# SI009C014 65/346
# IT0791215 66/346
# IT078C008 67/346
# IT6516636 68/346
# IT6516726 69/346
# IT6516771 70/346
# IT651C006 71/346
# IT651C007 72/346
# IT651C008 73/346
# IT651C009 74/346
# IT651C010 75/346
# IT0790667 76/346
dirName = os.path.join('/rds/general/project/c3nl_djs_imaging_data/live/data/raw/', projectID)

# Create target Directory if don't exist
if not os.path.exists(dirName):
    os.mkdir(dirName)
    print("Directory " , dirName ,  " Created ")
else:    
    print("Directory " , dirName ,  " already exists")
    
Results_Dir = dirName # needs to exist or next cell will throw error
# Out:
# ('Directory ', '/rds/general/project/c3nl_djs_imaging_data/live/data/raw/BIO-AX-TBI', ' already exists')

# %% [markdown]
# ### Download datasets
# This script will look into the predefined project. Check the printed output to look for duplicates and incomplete datasets.

# %%
import glob 

subjectCounter = 0
for s, subjectID in enumerate(subjects):
    subjectLabel = central.select.project(projectID).subject(subjectID).label()
    
    for experimentID in allSessions[s]:
            scans = central.select.project(projectID).subject(subjectID).experiments(experimentID).scans()
            scanIDs = scans.get()
            
            coll = central.select.project(projectID).subject(subjectID).experiments(experimentID)
            for ese in coll:
                explab = ese.attrs.get('label')
            
            # Check if data has already been pulled
            dataCheck = glob.glob(Results_Dir + "/" + subjectLabel + "/*" + explab )
            #print("sub label is: " + subjectLabel)
            #print("exp label is: " + explab)
            dataCheck = ''.join(dataCheck) # covert list to string
            #print("data path is: " + dataCheck)
            if not os.path.exists(dataCheck):
                print("Downloading:", explab)        
                number_subjects+=1
            
                if len(scanIDs) == 0:
                    print("There are no scans to download for", explab)
                else:
                    filenames = central.select.project(projectID).subject(subjectID).experiment(experimentID).scans()
                    filenames.download(Results_Dir, type='ALL', extract=False, removeZip=True)   
            else:
                print(explab + " already pulled")
print "The total number of scanning sessions downloaded is = " + str(number_subjects)
# Out:
# IT4381265_v1 already pulled
# SI0092660_v1 already pulled
# MINI_COAT002 already pulled
# IT4381266_v1 already pulled
# IT4381269_v1 already pulled
# IT4381272_v1 already pulled
# ('Downloading:', 'COAT_HC_076')
# IT079C001_v1 already pulled
# IT6516127_v1 already pulled
# SI0092827_v1 already pulled
# UK0010084_v1 already pulled
# UK0010084_v3 already pulled
# UK0010084_v2 already pulled
# IT079C006_v1 already pulled
# CH001C004_v1 already pulled
# UK0010043_v2 already pulled
# IT078C005_v1 already pulled
# IT4381513_v1 already pulled
# COAT_HC046 already pulled
# BIOAX_UK0010083_v1 already pulled
# UK0010083_v3 already pulled
# UK0010083_v2 already pulled
# IT4381525_v1 already pulled
# CH001C010_v1 already pulled
# CH001C008_v1 already pulled
# SI009C006_v1 already pulled
# SI009C007_v1 already pulled
# IT078C007_v1 already pulled
# SI009C008_v1 already pulled
# SI009C009_v1 already pulled
# SI009C010_v1 already pulled
# SI009C011_v1 already pulled
# IT651C001_v1 already pulled
# IT651C002_v1 already pulled
# CH0010016_v1 already pulled
# CH0010016_v2 already pulled
# CH0010016_v3 already pulled
# CH0010014_v1 already pulled
# ('Downloading:', 'HBI_16_V2')
# COAT0029 already pulled
# COAT0029_1 already pulled
# UK0010044_v1 already pulled
# UK0010044_v2 already pulled
# UK0010044_v3 already pulled
# IT4381209_v1 already pulled
# IT4381273_v1 already pulled
# IT4381274_v1 already pulled
# CHLAU001_unlabelled already pulled
# CH0010001_v1 already pulled
# CH0010001_v2 already pulled
# CH0010001_v3 already pulled
# IT6516397_v1 already pulled
# UK001_0078 already pulled
# UK0010078_v3 already pulled
# UK0010078_v2 already pulled
# IT438C001_v1 already pulled
# UK0010074_v1 already pulled
# UK001_0074_v2 already pulled
# RUGBY_SC01 already pulled
# IT6516386_v1 already pulled
# IT438C002_v1 already pulled
# RUGBY_SC02 already pulled
# COAT_HC038 already pulled
# IT438C003_v1 already pulled
# IT0781663_v1 already pulled
# IT0781663_v2 already pulled
# IT0781663_v3 already pulled
# SI0092710_v1 already pulled
# IT0794629_v1 already pulled
# IT079C005_v1 already pulled
# COAT_HC047 already pulled
# COAT_HC049 already pulled
# CH001C003_v1 already pulled
# CH001C007_v1 already pulled
# IT6516576_v1 already pulled
# CH001C014_v1 already pulled
# IT0791082_v1 already pulled
# CH0010034_v1 already pulled
# CH0010034_v2 already pulled
# SI0092993_v1 already pulled
# SI0092997_v1 already pulled
# SI009C013_v1 already pulled
# CH0010038_v1 already pulled
# SI009C014_v1 already pulled
# IT0791215_v1 already pulled
# IT078C008_v1 already pulled
# IT6516636_v1 already pulled
# IT6516726_v1 already pulled
# IT6516771_v1 already pulled
# IT651C006_v1 already pulled
# IT651C007_v1 already pulled
# IT651C008_v1 already pulled
# IT651C009_v1 already pulled
# IT651C010_v1 already pulled
# IT0790667_v1 already pulled
# CHLAU005_v1 already pulled
# IT0790943_v1 already pulled
# CH0010025_v1 already pulled
# CH0010025_v2 already pulled
# CH0010025_v3 already pulled
# COAT_HC041 already pulled
# CH001C001_v1 already pulled
# CH0010031_v1 already pulled
# ('Downloading:', 'CH0010031_v3')
# CH0010031_v2 already pulled
# CH001C002_v1 already pulled
# COAT_RC already pulled
# IT6516421_v1 already pulled
# UK0010086_v1 already pulled
# ('Downloading:', 'UK0010086_V3')
# UK0010086_v2 already pulled
# COAT_HC042 already pulled
# CH001C005_v1 already pulled
# COAT_HC040 already pulled
# COAT_HC043 already pulled
# IT079C007_v1 already pulled
# IT6516398_v1 already pulled
# IT0781841_v1 already pulled
# ('Downloading:', 'IT0781841_v3')
# IT0781841_v2 already pulled
# COAT_HC044 already pulled
# UK002_0004 already pulled
# UK0020004_v2 already pulled
# COAT_HC045 already pulled
# IT0781367_v1 already pulled
# IT0781378_v1 already pulled
# IT0781378_v2 already pulled
# IT0781378_v3 already pulled
# IT0781394_v1 already pulled
# IT0781394_v2 already pulled
# IT0781394_v3 already pulled
# IT0781414_v1 already pulled
# LausannePhantom_220318 already pulled
# LausannePhantom_080518 already pulled
# LausannePhantom_180718 already pulled
# LausannePhantom_021118 already pulled
# LausannePhantom_010419 already pulled
# LausannePhantom_07012020 already pulled
# CH0010019_v1 already pulled
# CH0010019_v2 already pulled
# CH0010019_v3 already pulled
# IT4381275_v1 already pulled
# IT4381522_v1 already pulled
# IT6516539_v1 already pulled
# SI009C004_v1 already pulled
# IT6516574_v1 already pulled
# SI009C012_v1 already pulled
# COAT_0161 already pulled
# UK0010106_v2 already pulled
# IT078C006_v1 already pulled
# IT651C003_v1 already pulled
# NMMBO_G004N17 already pulled
# NMMBO_G092P18 already pulled
# NMMBO_G092P18_FU2 already pulled
# NMMBO_G094P18 already pulled
# NMMBO_G094P18v2 already pulled
# IT0794464_v1 already pulled
# ('Downloading:', 'UK0010101_v1')
# BIOAX_PILOT_GZ already pulled
# BIOAX_PILOT3 already pulled
# CH0010008_v1 already pulled
# CH0010011_v1 already pulled
# CH0010011_v2 already pulled
# CH0010011_v3 already pulled
# CHLAU011_v1 already pulled
# CHLAU009_v1_unlabelled already pulled
# CHLAU009_v1_labelled already pulled
# COAT_HC048 already pulled
# IT079C008_v1 already pulled
# UK0010087_v1 already pulled
# UK0010087_v2 already pulled
# IT079C009_v1 already pulled
# IT078C004_v1 already pulled
# UK0010088_v1 already pulled
# SI009C003_v1 already pulled
# IT0790989_v1 already pulled
# IT079C010_v1 already pulled
# IT6516497_v1 already pulled
# CH001C009_v1 already pulled
# CH001C006_v1 already pulled
# CH0010028_v1 already pulled
# CH0010028_v3 already pulled
# CH0010028_v2 already pulled
# IT6516519_v1 already pulled
# CH001C012_v1 already pulled
# CH001C013_v1 already pulled
# IT6516534_v1 already pulled
# BIOAX_COAT0147_V1 already pulled
# NMMBO_G015N19 already pulled
# UK001_0090 already pulled
# NMMBO_G023N19 already pulled
# UK001_0093 already pulled
# NMMBO_G098P18 already pulled
# CH0010002_v1 already pulled
# CHLAU006_v1_unlabelled already pulled
# CH0010006_v1 already pulled
# CH0010006_v2 already pulled
# CH0010006_v1_correct already pulled
# CH0010006_v3 already pulled
# CH0010013_v1 already pulled
# CH0010012_v1 already pulled
# CH0010012_v2 already pulled
# CH0010012_v3 already pulled
# COAT004 already pulled
# UK0010022_v1 already pulled
# BIOAX_UK0010022_V2 already pulled
# UK0010022_v3 already pulled
# IT0781446_v1 already pulled
# IT0781446_v2 already pulled
# IT0781446_v3 already pulled
# IT0781458_v1 already pulled
# IT0781458_v3 already pulled
# IT0781464_v1 already pulled
# IT0781464_v3 already pulled
# IT0781464_v2 already pulled
# IT0781488_v1 already pulled
# IT0781488_v2 already pulled
# IT0781490_v1 already pulled
# IT0794419_v1 already pulled
# IT0794466_v1 already pulled
# IT0794490_v1 already pulled
# COAT008 already pulled
# UK0010026_v1 already pulled
# UK0010026_v2 already pulled
# UK0010026_v3 already pulled
# IT0794494_v1 already pulled
# IT0794537_v1 already pulled
# IT0794559_v1 already pulled
# SI009002V_v1 already pulled
# SI0092414_v1 already pulled
# SI0092489_v1 already pulled
# COAT0016 already pulled
# UK0010033_v1 already pulled
# UK0010033_v2 already pulled
# COAT0013_v1 already pulled
# UK0010028_v1 already pulled
# UK0010028_V2 already pulled
# UK0010013_v3 already pulled
# CH0010010_v1 already pulled
# CH0010010_v2 already pulled
# COAT0014 already pulled
# UK0010029_v1 already pulled
# UK0010029_v2 already pulled
# UK0010029_v3 already pulled
# UK0010036_v1 already pulled
# UK0010036_v2 already pulled
# UK0010036_v3 already pulled
# SI0092452_v1 already pulled
# SI0092460_v1 already pulled
# SI0092470_v1 already pulled
# UK0010047_V1 already pulled
# UK0010047_v2 already pulled
# UK0010047_V3 already pulled
# COAT0018_v1 already pulled
# UK0010032_v1 already pulled
# NMMBO_G123P18 already pulled
# UK0010041_v1 already pulled
# IT0794575_v1 already pulled
# COAT_HC027 already pulled
# CH0010017_v1 already pulled
# CH0010017_v2 already pulled
# CH0010017_v3 already pulled
# NMMBO_G013N19 already pulled
# UK0020017 already pulled
# UK0010118_v2 already pulled
# IT651C005_v1 already pulled
# IT651C004_v1 already pulled
# IT0791172_v1 already pulled
# BIOAX_COAT0064 already pulled
# CH001C015_v1 already pulled
# IT438C006_v1 already pulled
# IT438C005_v1 already pulled
# IT438C004_v1 already pulled
# SI009C015_v1 already pulled
# ARCHIVED already pulled
# IT079C015_v1 already pulled
# IT438C007_v1 already pulled
# IT078C010_v1 already pulled
# IT078C011_v1 already pulled
# IT078C012_v1 already pulled
# IT078C014_v1 already pulled
# IT0791184_v1 already pulled
# IT078C009_v1 already pulled
# IT078C017_v1 already pulled
# IT078C013_v1 already pulled
# IT078C015_v1 already pulled
# UK0010121_v1 already pulled
# UK0010121_V2 already pulled
# IT438C008_v1 already pulled
# IT438C009_v1 already pulled
# BIOAX_PILOT_FM already pulled
# BIOAX_PILOT2 already pulled
# 17_05_30-14_41_18-DST-1_3_12_2_1107_5_2_36_40436 already pulled
# UK001-0034 already pulled
# UK0010034_v1 already pulled
# IT0794451_v1 already pulled
# G125P18_NMMBO already pulled
# UK0010042_v1 already pulled
# UK0010042_v2 already pulled
# UK0010042_V3 already pulled
# UK0010042_V2 already pulled
# IT0781607_v1 already pulled
# IT0781607_v2 already pulled
# IT0781607_v3 already pulled
# IT0794583_v1 already pulled
# IT0794589_v1 already pulled
# IT0794607_v1 already pulled
# IT0794638_v1 already pulled
# IT4381212_v1 already pulled
# IT4381216_v1 already pulled
# IT4381217_v1 already pulled
# IT4381253_v1 already pulled
# SI0092579_v1 already pulled
# IT4381271_v1 already pulled
# SI0092627_v1 already pulled
# CH0010015_v1 already pulled
# CH0010015_v2 already pulled
# CH0010015_v3 already pulled
# COAT_HC026 already pulled
# BIOAX_UK0010098_v1 already pulled
# SI009C005_v1 already pulled
# BIOAX_UK0010089_v1 already pulled
# CH0010037_v1 already pulled
# CH0010037_v2 already pulled
# BIOAX_UK0010097_v1 already pulled
# UK0010097_v2 already pulled
# IT0781670_v1 already pulled
# IT0781670_v2 already pulled
# IT0781670_v3 already pulled
# SI0092626_v1 already pulled
# UK0010031_BIOAX_TBI already pulled
# UK0010031_v1 already pulled
# UK0010031_v2 already pulled
# UK0010031_V3 already pulled
# G124P18_NMMBO already pulled
# UK0010039_v1 already pulled
# UK0010037_BIOAX_TBI already pulled
# UK0010037_v1 already pulled
# UK0010037_v2 already pulled
# UK0010037_v3 already pulled
# UK001_BIOAX_TBI already pulled
# UK001_0038 already pulled
# UK001_0038_1 already pulled
# UK0010038_v2 already pulled
# UK0010038_v3 already pulled
# IT4381297_v1 already pulled
# NMMBO_G141N18 already pulled
# COAT_HC032 already pulled
# NMMBO_G146N18 already pulled
# UK001_0056 already pulled
# UK0010056 already pulled
# IT0781681_v1 already pulled
# IT0790779_v1 already pulled
# SI0092707_v1 already pulled
# SI0092744_v1 already pulled
# SI0092761_v1 already pulled
# CH0010009_v1 already pulled
# CH0010005_v1 already pulled
# SI0092549_v1 already pulled
# SI0092717_v1 already pulled
# UK0020010 already pulled
# UK0010107 already pulled
# UK0010107_v2 already pulled
# COAT_HV068 already pulled
# COAT_HV069 already pulled
# BioAx_COAT0166 already pulled
# UK0010113_v2 already pulled
# CH001C011_v1 already pulled
# CH0010035_v1 already pulled
# CH0010035_v2 already pulled
# SI0092985_v1 already pulled
# IT6516635_v1 already pulled
# IT079C011_v1 already pulled
# COAT_MC072 already pulled
# IT6516586_v1 already pulled
# IT6516648_v1 already pulled
# COAT_HC071 already pulled
# COAT_HC073 already pulled
# IT079C012_v1 already pulled
# UK0010060_V2 already pulled
# UK0010060_v3 already pulled
# IT079C014_v1 already pulled
# IT079C013_v1 already pulled
# IT0791157_v1 already pulled
# IT0791132_v1 already pulled
# BIOAX_COAT_HC075 already pulled
# UK001_0052 already pulled
# UK0010052 already pulled
# IT0790778_v1 already pulled
# IT0790796_v1 already pulled
# IT0781733_v1 already pulled
# IT0781733_v3 already pulled
# IT0781733_v2 already pulled
# CIF_CONTROL073 already pulled
# UK0010061_v1 already pulled
# UK0010061_V3 already pulled
# UK0010061_v2 already pulled
# UK0010059_v1 already pulled
# UK0010059_v2 already pulled
# UK0010059_v3 already pulled
# CH0010024_v1 already pulled
# CH0010024_v2 already pulled
# CH0010024_v3 already pulled
# IT0790822_v1 already pulled
# LjubianaPhantom_101118 already pulled
# LjubianaPhantom_10112018 already pulled
# LjubianaPhantom_30032019 already pulled
# PoliclinicoPhantom_121218 already pulled
# PoliclinicoPhantom_200319 already pulled
# PoliclinicoPhantom_07012020 already pulled
# PoliclinicoPhantom_12122018 already pulled
# NiguardaPhantom_071118 already pulled
# NiguardaPhantom_07112018 already pulled
# NiguardaPhantom_08012020 already pulled
# NiguardaPhantom_28032019 already pulled
# CareggiPhantom_081118 already pulled
# CareggiPhantom_25032019 already pulled
# CareggiPhantom_08112018 already pulled
# IT078C001_v1 already pulled
# IT078C002_v1 already pulled
# IT079C002_v1 already pulled
# IT079C003_v1 already pulled
# IT079C004_v1 already pulled
# IT4381414_v1 already pulled
# IT0790891_v1 already pulled
# IT0790844_v1 already pulled
# IT0791228_v1 already pulled
# IT651C012_v1 already pulled
# IT651C011_v1 already pulled
# SI0093093_v1 already pulled
# IT0791274_v1 already pulled
# IT651C014_v1 already pulled
# IT651C015_v1 already pulled
# IT6516829_v1 already pulled
# IT0791308_v1 already pulled
# IT438C010_v1 already pulled
# IT438C012_v1 already pulled
# CH0010041_v2 already pulled
# CH0010041_v1 already pulled
# UK0010128_V1 already pulled
# ('Downloading:', 'CH0010030_v3')
# CH0010030_v2 already pulled
# CH0010030_v1 already pulled
# ('Downloading:', 'UK0010127_V2')
# UK0010127_v1 already pulled
# IT438C013_v1 already pulled
# IT6516814_v1 already pulled
# IT438C011_v1 already pulled
# SI009C002_v1 already pulled
# IT6516826_v1 already pulled
# IT0791295_v1 already pulled
# IT651C013_v1 already pulled
# SI009C001_v1 already pulled
# CH0010042_v2 already pulled
# CH0010042_v1 already pulled
# CH0010020_v1 already pulled
# CH0010020_v2 already pulled
# CH0010020_v3 already pulled
# IT0791321_v1 already pulled
# IT0791334_v1 already pulled
# IT651C016_v1 already pulled
# UK0010141_v1 already pulled
# IT0791356_v1 already pulled
# UK0010144_v1 already pulled
# UK0010145_v1 already pulled
# IT0791368_v1 already pulled
# IT0791370_v1 already pulled
# NMMBO_G131P19 already pulled
# UK0010146_v1 already pulled
# IT0791384_v1 already pulled
# IT0791395_v1 already pulled
# IT0791400_v1 already pulled
# IT0791429_v1 already pulled
# UK0010148_v1 already pulled
# UK0010149_v1 already pulled
# IT4381368_v1 already pulled
# UK0010150_v1 already pulled
# IT0791511_v1 already pulled
# SI0093321_v1 already pulled
# IT0791535_v1 already pulled
# SI0093339_v1 already pulled
# CHLAU001_v2 already pulled
# CH0010048_v1 already pulled
# ('Downloading:', 'CH0010047_v1')
# ('Downloading:', 'CH0010049_v1')
# UK0010111_v2 already pulled
# IT0791558_v1 already pulled
# CH0010046_v1 already pulled
# BIOAX_COAT_HC074 already pulled
# The total number of scanning sessions downloaded is = 10

# %% [markdown]
# ## Sweet now we're rolling!
# To make life easy all our labs notebooks are going assume a BIDS format.
# As data curating can be a pain in the derrière, lets run a nice little function to sort that for us ;)
#
# ## Dependencies
#
# #### A CIF_config.json has been created to match MRI acquisitions and label them in the correct format.
# This may need to be updated if new seqences are being collected.
# Requires the labels from the scan card for each acquisition being formated (NOTE: How these are displayed on the XNAT website unhelpfuly does not necessarily match with the actual data labels!)
#
# #### Index files
# * I have used XDC (xnat data cliant) to pull metaData about scan labels from xnat.
#
# * The bids scripts are hardcoded to look for this metaData in a indexFiles directory within the working dir. This should contain two files for the project PROJECT_experiments.csv and PROJECT_subject.csv
#
# * This requires local setup. I have a function that runs through a list of TBI projects on xnat and downloads the metadata. If a proejct is not in the imaging directory try the XDC setup below.
#
# * The following XDC function can be used to pull project and subject information from xnat
#
#
# ### XDC setup
#
# Install via the following instructions:
# https://wiki.xnat.org/xnat-tools/xnatdataclient
#
#
# Use some lines like the following to pull the csv files used for indexing and renaming the files

# %%
# XDC is an alias set in .bash_profile to the function which can be downloaded in the above link

XDC -u USERNAME -p PASSWORD -r "http://wmec-transtec1.hh.med.ic.ac.uk:/data/archive/projects/PROJECT/experiments?format=csv" -o PROJECT_experiments
    
XDC -u USERNAME -p PASSWORD -r "http://wmec-transtec1.hh.med.ic.ac.uk:/data/archive/projects/PROJECT/subjects?format=csv" -o PROJECT_subject

# %% [markdown]
# ## Extracting and indexing data from xnat
#
# The following functions are in the dependencies folder on the Imperial HPC along with the CIF_config.json file
#
# #### 1: bids_1_preproc -i project
#     Unzips & indexes files downloaded from XNAT with more meaningfull labels such as participant ID and scan session.
#     This sets up the initial file structure to run the conversion to BIDS.
#
#
# #### 2: bids_2_proc -i project -c config.json
#     Loops over all subjects->sessions->modalities->scans and converts DICOMS to NIFTI.
#     The labels for each of the scans on the scan card are then converted to match the BIDS format and file structure
#
# #### Sources of error
# * Conversion to nii at this point should be robust and all data will be in raw under the project name
# * Missing data in source directory is likely due to a new exception in how something was named on the scanner - this should be added to the config.json file. Be careful not to clash with similar names.
# * This works well for data comming off the CIF scanner (Imperial). Data from new sites have to be checked as something in the structure may cause unexpected outcomes.
